# %%
from keras.layers import Input, Dense, Flatten, Reshape
from keras.models import Model
from keras.datasets import mnist
import numpy as np

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test  = x_test .astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test  = np.reshape(x_test,  (len(x_test),  28, 28, 1))

def create_deep_dense_ae():
    # Размерность кодированного представления
    encoding_dim = 49

    # Энкодер
    input_img = Input(shape=(28, 28, 1))
    flat_img = Flatten()(input_img)
    x = Dense(encoding_dim*3, activation='relu')(flat_img)
    x = Dense(encoding_dim*2, activation='relu')(x)
    encoded = Dense(encoding_dim, activation='linear')(x)
    
    # Декодер
    input_encoded = Input(shape=(encoding_dim,))
    x = Dense(encoding_dim*2, activation='relu')(input_encoded)
    x = Dense(encoding_dim*3, activation='relu')(x)
    flat_decoded = Dense(28*28, activation='sigmoid')(x)
    decoded = Reshape((28, 28, 1))(flat_decoded)
    
    # Модели
    encoder = Model(input_img, encoded, name="encoder")
    decoder = Model(input_encoded, decoded, name="decoder")
    autoencoder = Model(input_img, decoder(encoder(input_img)), name="autoencoder")
    return encoder, decoder, autoencoder
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def plot_digits(*args):
    args = [x.squeeze() for x in args]
    n = min([x.shape[0] for x in args])
    
    plt.figure(figsize=(2*n, 2*len(args)))
    for j in range(n):
        for i in range(len(args)):
            ax = plt.subplot(len(args), n, i*n + j + 1)
            plt.imshow(args[i][j])
            plt.gray()
            ax.get_xaxis().set_visible(False)
            ax.get_yaxis().set_visible(False)

    plt.show()

# %%
d_encoder, d_decoder, d_autoencoder = create_deep_dense_ae()
d_autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

d_autoencoder.summary()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# encoder (Functional)         (None, 49)                134750
# _________________________________________________________________
# decoder (Functional)         (None, 28, 28, 1)         135485
# =================================================================
# Total params: 270,235
# Trainable params: 270,235
# Non-trainable params: 0
# _________________________________________________________________

# %%
d_autoencoder.fit(x_train, x_train,
                  epochs=100,
                  batch_size=256,
                  shuffle=True,
                  validation_data=(x_test, x_test))
# Out:
# Epoch 1/100
# 235/235 [==============================] - 6s 20ms/step - loss: 0.2299 - val_loss: 0.1477
# Epoch 2/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1339 - val_loss: 0.1217
# Epoch 3/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1178 - val_loss: 0.1111
# Epoch 4/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.1090 - val_loss: 0.1044
# Epoch 5/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1035 - val_loss: 0.1000
# Epoch 6/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0996 - val_loss: 0.0969
# Epoch 7/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0963 - val_loss: 0.0936
# Epoch 8/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.0936 - val_loss: 0.0913
# Epoch 9/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.0915 - val_loss: 0.0900
# Epoch 10/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.0899 - val_loss: 0.0884
# Epoch 11/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0887 - val_loss: 0.0872
# Epoch 12/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0875 - val_loss: 0.0864
# Epoch 13/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0867 - val_loss: 0.0858
# Epoch 14/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0857 - val_loss: 0.0843
# Epoch 15/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0850 - val_loss: 0.0841
# Epoch 16/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.0842 - val_loss: 0.0835
# Epoch 17/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.0836 - val_loss: 0.0829
# Epoch 18/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.0831 - val_loss: 0.0820
# Epoch 19/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0826 - val_loss: 0.0816
# Epoch 20/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0820 - val_loss: 0.0813
# Epoch 21/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0816 - val_loss: 0.0809
# Epoch 22/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0812 - val_loss: 0.0803
# Epoch 23/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0808 - val_loss: 0.0804
# Epoch 24/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0804 - val_loss: 0.0797
# Epoch 25/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0800 - val_loss: 0.0795
# Epoch 26/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0797 - val_loss: 0.0791
# Epoch 27/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.0794 - val_loss: 0.0788
# Epoch 28/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0790 - val_loss: 0.0785
# Epoch 29/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.0787 - val_loss: 0.0785
# Epoch 30/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0785 - val_loss: 0.0778
# Epoch 31/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0782 - val_loss: 0.0776
# Epoch 32/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.0780 - val_loss: 0.0774
# Epoch 33/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0777 - val_loss: 0.0774
# Epoch 34/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0775 - val_loss: 0.0769
# Epoch 35/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0773 - val_loss: 0.0771
# Epoch 36/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0772 - val_loss: 0.0770
# Epoch 37/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0770 - val_loss: 0.0767
# Epoch 38/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0768 - val_loss: 0.0764
# Epoch 39/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0766 - val_loss: 0.0760
# Epoch 40/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0765 - val_loss: 0.0761
# Epoch 41/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0763 - val_loss: 0.0759
# Epoch 42/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0762 - val_loss: 0.0760
# Epoch 43/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0760 - val_loss: 0.0757
# Epoch 44/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0759 - val_loss: 0.0758
# Epoch 45/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0758 - val_loss: 0.0753
# Epoch 46/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0756 - val_loss: 0.0753
# Epoch 47/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0755 - val_loss: 0.0752
# Epoch 48/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0753 - val_loss: 0.0750
# Epoch 49/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0752 - val_loss: 0.0752
# Epoch 50/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0751 - val_loss: 0.0747
# Epoch 51/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0750 - val_loss: 0.0745
# Epoch 52/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0748 - val_loss: 0.0748
# Epoch 53/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0748 - val_loss: 0.0744
# Epoch 54/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0747 - val_loss: 0.0746
# Epoch 55/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0746 - val_loss: 0.0742
# Epoch 56/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0744 - val_loss: 0.0744
# Epoch 57/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0743 - val_loss: 0.0740
# Epoch 58/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0743 - val_loss: 0.0742
# Epoch 59/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0742 - val_loss: 0.0740
# Epoch 60/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.0741 - val_loss: 0.0740
# Epoch 61/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.0740 - val_loss: 0.0738
# Epoch 62/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0740 - val_loss: 0.0737
# Epoch 63/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0739 - val_loss: 0.0736
# Epoch 64/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0738 - val_loss: 0.0736
# Epoch 65/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0737 - val_loss: 0.0736
# Epoch 66/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0737 - val_loss: 0.0734
# Epoch 67/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0736 - val_loss: 0.0738
# Epoch 68/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0735 - val_loss: 0.0733
# Epoch 69/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0735 - val_loss: 0.0733
# Epoch 70/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0734 - val_loss: 0.0733
# Epoch 71/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0734 - val_loss: 0.0731
# Epoch 72/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0733 - val_loss: 0.0731
# Epoch 73/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0732 - val_loss: 0.0730
# Epoch 74/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0732 - val_loss: 0.0731
# Epoch 75/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0731 - val_loss: 0.0734
# Epoch 76/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0731 - val_loss: 0.0731
# Epoch 77/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0731 - val_loss: 0.0730
# Epoch 78/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0730 - val_loss: 0.0730
# Epoch 79/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0730 - val_loss: 0.0728
# Epoch 80/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0729 - val_loss: 0.0729
# Epoch 81/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0729 - val_loss: 0.0726
# Epoch 82/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0728 - val_loss: 0.0728
# Epoch 83/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0728 - val_loss: 0.0726
# Epoch 84/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0727 - val_loss: 0.0727
# Epoch 85/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0727 - val_loss: 0.0728
# Epoch 86/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0726 - val_loss: 0.0723
# Epoch 87/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0725 - val_loss: 0.0725
# Epoch 88/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0725 - val_loss: 0.0726
# Epoch 89/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0725 - val_loss: 0.0723
# Epoch 90/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0724 - val_loss: 0.0724
# Epoch 91/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0724 - val_loss: 0.0723
# Epoch 92/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0724 - val_loss: 0.0723
# Epoch 93/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0724 - val_loss: 0.0723
# Epoch 94/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0723 - val_loss: 0.0723
# Epoch 95/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0723 - val_loss: 0.0721
# Epoch 96/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0722 - val_loss: 0.0722
# Epoch 97/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0722 - val_loss: 0.0720
# Epoch 98/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0721 - val_loss: 0.0722
# Epoch 99/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0721 - val_loss: 0.0720
# Epoch 100/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0721 - val_loss: 0.0720

# %%
len(x_test)
# Out:
# 10000

# %%
n = 10

imgs = x_test[100:100+n]
encoded_imgs = d_encoder.predict(imgs, batch_size=n)

decoded_imgs = d_decoder.predict(encoded_imgs, batch_size=n)

plot_digits(imgs, decoded_imgs)

# %%
# !git clone https://git@github.com:erofale/encoderProject.git
